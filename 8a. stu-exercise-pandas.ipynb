# %% [markdown]
# # Pandas exercises
#
# In this activity, we will perform some common operation in pandas.

# %%
import pandas as pd

# %%
# read a CSV into a DataFrame
df = pd.read_csv("https://raw.githubusercontent.com/AustralianSDAF/python-data-visualisation/main/perth_house_prices.csv")

# %%
df.head(5)
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160      2003.0     18300  Cockburn Central Station
# 1        351         139      2013.0     26900           Kwinana Station
# 2        719          86      1979.0     22600           Challis Station
# 3        651          59      1953.0     17900           Midland Station
# 4        466         131      1998.0     11200        Bassendean Station
#
#    NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# ...

# %% [markdown]
# ## Activity 1

# %%
# obtain the count of the number of houses in bentley
bentley_houses = 

# obtain the count of the number of houses in Peppermint Grove
peppermint_houses = 

# obtain the count of the number of rows that don't have data on ranking of nearest school
no_school_data = 

print(f"The number of houses in bentley are: {bentley_houses}")
print(f"The number of houses in peppermint grove are: {peppermint_houses}")
print(f"The number of houses that don't have data on nearest school ranking: {no_school_data}")
# Out:
# The number of houses in bentley are: 81
# The number of houses in peppermint grove are: 41
# The number of houses that don't have data on nearest school ranking: 10952

# %% [markdown]
# ## Activity 2

# %%
# get a unique list of all suburbs using .unique()
# Out:
# array(['South Lake', 'Wandi', 'Camillo', 'Bellevue', 'Lockridge',
#        'Mount Richon', 'Hilbert', 'Waikiki', 'Hamersley', 'Bayswater',
#        'Carmel', 'Butler', 'Balga', 'Hammond Park', 'Wattle Grove',
#        'Bull Creek', 'Bullsbrook', 'Maida Vale', 'Koongamia',
#        'Mount Nasura', 'Forrestdale', 'Atwell', 'Ashby', 'Woodbridge',
#        'Bicton', 'Singleton', 'South Guildford', 'Armadale', 'Kenwick',
#        'Hamilton Hill', 'Port Kennedy', 'Roleystone', 'Glen Forrest',
#        'Secret Harbour', 'Herne Hill', 'Gwelup', 'Harrisdale',
#        'North Fremantle', 'Quinns Rocks', 'Spearwood', 'Parkwood',
#        'Tapping', 'Thornlie', 'Baldivis', 'Kensington', 'Kiara', 'Menora',
#        'Southern River', 'Bibra Lake', 'Swanbourne', 'The Vines',
#        'Stratton', 'North Beach', 'Haynes', 'Madeley', 'Wembley Downs',
#        'Bentley', 'Manning', 'Warwick', 'Queens Park', 'Medina',
#        'Kalamunda', 'Merriwa', 'Aubin Grove', 'Karrinyup',
# ...

# %% [markdown]
# ## Activity 3

# %%
# get the unique list of SUBURBS that are within the boundary of Perth Modern School using .unique()
# Out:
# array(['Wembley', 'Subiaco', 'West Leederville', 'Daglish', 'West Perth',
#        'Shenton Park'], dtype=object)

# %% [markdown]
# ## Activity 5

# %%
# find the houses that are less than $800k and sort by nearest school ranking in ascending order.
# Out:
#                        ADDRESS            SUBURB   PRICE  BEDROOMS  BATHROOMS  \
# 27229       6 Robinson Terrace           Daglish  700000         3          2
# 28623        69/9 Delhi Street        West Perth  635000         3          2
# 24841        5/370 Barker Road           Subiaco  600000         3          1
# 5984          148 Tower Street  West Leederville  752500         3          1
# 761          1/99 Roberts Road           Subiaco  450000         2          1
# 24797        5/1178 Hay Street        West Perth  407000         2          1
# 2865          11/3 Brigid Road           Subiaco  390000         1          1
# 26950            6 Kerr Street  West Leederville  715000         2          2
# 24793       5/11 Altona Street        West Perth  608000         2          2
# 6733          15/3 Brigid Road           Subiaco  443500         1          1
# 15656  28/237 Cambridge Street           Wembley  300000         2          1
# ...
